# %% [markdown]
# # Python BAsic Assignment-4

# %% [markdown]
# #### Question 1: What exactly is []?

# %% [markdown]
# [] represents an empty list, ie, a list with no elements.

# %% [markdown]
# #### Question 2 : In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %% [markdown]
# spam[2]='hello'

# %%
spam=[2,4,6,8,10]
print(spam)
spam[2]='hello'
print(spam)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ### Let's pretend the spam includes the list ['a','b','c','d'] for the next three queries.

# %% [markdown]
# #### Question 3: What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %% [markdown]
# '3' * 2 is 33 (since here 3 is a string and '3' * 2 means string multiplication). int('33') gives 33 as an integer and 33/11 gives the result as 3 and spam[3] is 'd'. Hence the answer is 'd'.

# %%
spam=['a','b','c','d']
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %% [markdown]
# #### Question 4 : What is the value of spam[-1]?

# %% [markdown]
# Indexing from backwards starts with -1 . Thus spam[-1] is 'd'.

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# #### Question 5 : What is the value of spam[:2]?

# %% [markdown]
# spam[:2] returns all the values of the list spam starting from 0 upto but excluding 2.

# %%
spam[0:2]
# Out:
# ['a', 'b']

# %% [markdown]
# ### Let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True] for the next three questions.

# %% [markdown]
# #### Question 6 : What is the value of bacon.index(&#39;cat&#39;)?

# %% [markdown]
# bacon.index('cat') returns the index at which cat is written( although this function returns the index of first occurence of 'cat')

# %%
bacon=[3.14,'cat',11,'cat',True]
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# #### Question 7 : How does bacon.append(99) change the look of the list value in bacon?

# %% [markdown]
# append function appends(adds) new element at the end of the list.

# %%
bacon.append(99)
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# #### Question 8 : How does bacon.remove('cat') change the look of the list in bacon?

# %% [markdown]
# remove() method removes the first occurence of the element from the list.
# So bacon.remove('cat') removes the cat from 1st index.

# %%
bacon.remove('cat')
print(bacon)
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# #### Question 9 : What are the list concatenation and list replication operators?

# %% [markdown]
# The operator for list concatenation is '+', while the operator for string replication is '*'.

# %%
l1=['a','b','c','d']
l2=['e','f','g','h']
print(l1+l2)
print(l1*3)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
# ['a', 'b', 'c', 'd', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'd']

# %% [markdown]
# #### Question 10 : What is difference between the list methods append() and insert()?

# %% [markdown]
# append() method appends (adds) element at the end if the list, while with insert() function we can insert (add) an element at any desired position.

# %%
l3=[1,2,3,4,5]
l3.append(6)    # it appends 6 at end
l3.insert(3,7)   # it inserts 7 at 3rd position
l3
# Out:
# [1, 2, 3, 7, 4, 5, 6]

# %% [markdown]
# #### Question 11 : What are the two methods for removing items from a list?

# %% [markdown]
# remove() and pop() are two methods for removig items from a list.

# %% [markdown]
# #### Question 12: Describe how list values and string values are identical.

# %% [markdown]
# Both string and list:
# can be passed to len() method.
# are iterable objects
# can be used in for loops
# can be concatenated and replicated
# can be used with in and not in operators

# %% [markdown]
# #### Question 13 : What's the difference between tuples and lists?

# %% [markdown]
# LISTS are represented by [] , are mutable( that is we can add, remove ,alter the values in a list), while TUPLES are represnted by () , are immutable and their values can't be altered.

# %% [markdown]
# #### Question 14 : How do you type a tuple value that only contains the integer 42?

# %% [markdown]
# (42,) .( the trailing comma is mandatory, otherwise it is considered as an integer by python interpreter).

# %%
tup1=(42)
tup2=(42,)
print(type(tup1))
print(type(tup2))
# Out:
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# #### Question 15 : How do you get a list value's tuple form? How do you get a tuple values list form?

# %% [markdown]
# list() function is used to convert tuple into list and tuple() is used to convert list into tuple.

# %% [markdown]
# #### Question 16 : Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# They contain references to list values

# %% [markdown]
# #### Question 17 : How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
